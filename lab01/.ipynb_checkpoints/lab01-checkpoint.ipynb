# %% [markdown]
# # Task 1 noise average

# %% [markdown]
# > imoprt required libraries

# %%
# Import required libraries
import numpy as np
import cv2
import matplotlib.pyplot as plt
import os
from pathlib import Path

# %% [markdown]
# > display sample noisy images

# %%
# Specify the directory containing the images
image_dir = 'COMP9517_26T2_Lab1_Images'

# Load all 10 noisy images
images = []
num_images = 10

for i in range(1, num_images + 1):
    filename = f'Sydney_{i:02d}.jpg'
    filepath = os.path.join(image_dir, filename)
    img = cv2.imread(filepath)
    
    if img is not None:
        # Convert from BGR to RGB for proper display
        img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
        images.append(img_rgb)
        print(f"Loaded: {filename}, Shape: {img_rgb.shape}")
    else:
        print(f"Error could not load: {filename}")

print(f"\nSuccessfully loaded {len(images)} images")
# Out:
# Loaded: Sydney_01.jpg, Shape: (453, 660, 3)
# Loaded: Sydney_02.jpg, Shape: (453, 660, 3)
# Loaded: Sydney_03.jpg, Shape: (453, 660, 3)
# Loaded: Sydney_04.jpg, Shape: (453, 660, 3)
# Loaded: Sydney_05.jpg, Shape: (453, 660, 3)
# Loaded: Sydney_06.jpg, Shape: (453, 660, 3)
# Loaded: Sydney_07.jpg, Shape: (453, 660, 3)
# Loaded: Sydney_08.jpg, Shape: (453, 660, 3)
# Loaded: Sydney_09.jpg, Shape: (453, 660, 3)
# Loaded: Sydney_10.jpg, Shape: (453, 660, 3)
#
# Successfully loaded 10 images

# %% [markdown]
# > **Calculate *average* image**

# %%
# Display all 10 noisy images
fig, axes = plt.subplots(2, 5, figsize=(20, 8))
axes = axes.ravel()

for idx in range(len(images)):
    axes[idx].imshow(images[idx])
    axes[idx].set_title(f'Noisy Image {idx + 1}')
    axes[idx].axis('off')

plt.tight_layout()
plt.show()

# %% [markdown]
# >  Display result: single noisy image vs averaged image

# %%
# Convert list of images to numpy array for easier computation
images_array = np.array(images, dtype=np.float64)

# Calculate the average image
average_image = np.mean(images_array, axis=0)

# Convert back to uint8 for display
average_image_uint8 = np.uint8(average_image)

print(f"Average image shape: {average_image_uint8.shape}")
fig, axes = plt.subplots(1, 2, figsize=(15, 7))

# 显示第一张噪点图
axes[0].imshow(images[0])
axes[0].set_title('Single Noisy Image (Image 1)')
axes[0].axis('off')

# 显示平均去噪图
axes[1].imshow(average_image_uint8)
axes[1].set_title('Averaged Image (10 Images)')
axes[1].axis('off')

plt.tight_layout()
plt.show()
# Out:
# Average image shape: (453, 660, 3)
